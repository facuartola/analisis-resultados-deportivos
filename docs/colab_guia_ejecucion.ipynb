# %% [markdown]
# # TP Organización Empresarial - Análisis de Resultados Deportivos
# Notebook guía para ejecutar el flujo del proyecto desde Google Colab.

# %%
# !git config --global user.email "tu_email"
# !git config --global user.name "Tu Nombre Completo"

# %% [markdown]
# ## Clonar repositorio
# Reemplazar USUARIO por el usuario real de GitHub.

# %%
# !git clone https://github.com/USUARIO/analisis-resultados-deportivos.git
# %cd analisis-resultados-deportivos

# %% [markdown]
# ## Ejecutar análisis

# %%
# !python scripts/analisis_resultados.py

# %% [markdown]
# ## Ver archivos generados

# %%
# !ls resultados
# !cat resultados/resumen_torneo.txt
